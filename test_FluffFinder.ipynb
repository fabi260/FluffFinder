# %%
from FluffFinder import vanilla_fluff
import pandas as pd

# %%
test_data = pd.read_excel('TestData.xlsx', header=None ,names=['Index', 'Industry', 'Interest Category', 'Text', 'URL'])
# all_data = pd.read_excel('Dataset.xlsx', sheet_name='Dataset')
data = test_data
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
#print(data)
subset = data.iloc[[1, 4, 7]]
subset
# Out:
#    Index                    Industry      Interest Category  \
# 1      2  Technology and Electronics       General Interest
# 4      5  Technology and Electronics       Special Interest
# 7      8  Technology and Electronics  Professional Interest
#
#                                                 Text  \
# 1  SmartThings\nControl thousands of smart home p...
# 4  Introducing the GIGA Display Shield, a touch s...
# 7  Smart order fulfillment with IBM Sterling® Ord...
#
#                                                  URL Note   Criteria
# 1  https://www.samsung.com/uk/refrigerators/botto...  NaN  fulfilled
# 4  https://store.arduino.cc/products/giga-display...  NaN  fulfilled
# 7  https://www.ibm.com/products/order-management?...  NaN        NaN

# %%
to_evaluate = data

Scores = []
for i, text in enumerate(to_evaluate['Text']):
    sore = i+1 # vanilla_fluff(text)
    Scores.append(sore)

to_evaluate['Score'] = Scores

to_evaluate
# Out:
#     Index                    Industry      Interest Category  \
# 0       1  Technology and Electronics       General Interest
# 1       2  Technology and Electronics       General Interest
# 2       3  Technology and Electronics       General Interest
# 3       4  Technology and Electronics       Special Interest
# 4       5  Technology and Electronics       Special Interest
# ..    ...                         ...                    ...
# 85     86           Food and Beverage       Special Interest
# 86     87           Food and Beverage       Special Interest
# 87     88           Food and Beverage  Professional Interest
# 88     89           Food and Beverage  Professional Interest
# 89     90           Food and Beverage  Professional Interest
#
#                                                  Text  \
# 0   Filmmaking tools to support your creative visi...
# 1   SmartThings\nControl thousands of smart home p...
# 2   Experience limitless visuals and extraordinary...
# 3   Raspberry Pi OS\nThe latest release of Raspber...
# 4   Introducing the GIGA Display Shield, a touch s...
# ..                                                ...
# 85  Efficient Supply Chain Management\nEfficient S...
# 86  The three most popular snacks for people of al...
# 87  Chocolate, Sugar Snap and Orange Dessert Recip...
# 88  Added Sugars\nMars, Incorporated offers a vari...
# 89  To attach the nozzle, align the\nindicator mar...
#
#                                                   URL Note   Criteria  Score
# 0    https://pro.sony/en_GB/filmmaking/cinematic-look  NaN  fulfilled      1
# 1   https://www.samsung.com/uk/refrigerators/botto...  NaN  fulfilled      2
# 2   https://www.mi.com/global/product/xiaomi-tv-a-...  NaN  fulfilled      3
# 3   https://www.raspberrypi.com/products/raspberry...  NaN     unsure      4
# 4   https://store.arduino.cc/products/giga-display...  NaN  fulfilled      5
# ..                                                ...  ...        ...    ...
# 85  https://fmcgmistraltrading.com/the-importance-...  NaN        NaN     86
# 86  https://fmcgmistraltrading.com/biscuit-waffles...  NaN        NaN     87
# 87  https://www.greatbritishchefs.com/recipes/choc...  NaN        NaN     88
# 88  https://www.mars.com/about/policies-and-practi...  NaN        NaN     89
# 89         https://nitrosurge.guinness.com/manual.pdf  NaN        NaN     90
#
# [90 rows x 8 columns]
